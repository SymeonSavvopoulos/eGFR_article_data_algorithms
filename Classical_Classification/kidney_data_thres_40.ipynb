# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd

#from sklearn.datasets import load_boston 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import  accuracy_score, f1_score, confusion_matrix, roc_auc_score
from sklearn.model_selection import train_test_split

from collections import Counter

import matplotlib.pyplot as plt
import seaborn as sns

#plt.rcParams['figure.figsize'] = [20, 7]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## load dataset

# %%
data = pd.read_csv(r'/content/drive/MyDrive/imbalance/kidn_class40re_orig.csv')

# %%
data.head()
# Out:
#    do_age  gfr_in     speed  Y
# 0    61.0   91.23 -0.197095  0
# 1    62.0   25.10  0.247069  0
# 2    53.0   81.34 -0.370439  0
# 3    44.0   55.61 -0.138711  1
# 4    15.0   94.03 -0.396307  0

# %%
data.shape
data.Y.value_counts()
# Out:
# 0    274
# 1     88
# Name: Y, dtype: int64

# %%
# separate failures and non failures
data_0 = data[data['Y'] == 0]
data_1 = data[data['Y'] == 1]

# %%
data_0 = data_0.sample(n=274)

# %%
data = data_1.append(data_0)

data.Y.value_counts()
# Out:
# <ipython-input-263-96df2dc7510c>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data_1.append(data_0)
# 0    274
# 1     88
# Name: Y, dtype: int64

# %%
# check the number of 1s and 0s
count = data['Y'].value_counts()

print('Failed "1" :', count[1])
print('Not Failed "0":', count[0])

# print the percentage of question where target == 1
print(count[1]/count[0]* 100)
# Out:
# Failed "1" : 88
# Not Failed "0": 274
# 32.11678832116788

# %%
# check for null values
data.isnull().sum()
# Out:
# do_age    0
# gfr_in    0
# speed     0
# Y         0
# dtype: int64

# %%
plt.figure(figsize=(20,20))
sns.heatmap(data.corr(), annot=True)
plt.show()

# %% [markdown]
# ## Respose and Target variable

# %%
x = data.iloc[:, :-1]
y = data.iloc[:, -1]

# check length of 1's and 0's
one = np.where(y==1)
zero = np.where(y==0)
len(one[0]), len(zero[0])
# Out:
# (88, 274)

# %% [markdown]
# ## Train test split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Fit the model uing Logitic Regression

# %%
# create the object
model =  LogisticRegression()

model.fit(x, y)

y_predict = model.predict(x)

# %%
accuracy_score(y_predict, y)
# Out:
# 0.861878453038674

# %%
np.unique(y_predict)
# Out:
# array([0, 1])

# %% [markdown]
# ## The matrix trap

# %%
# import linrary
from xgboost import XGBClassifier

xgb_model = XGBClassifier().fit(x_train, y_train)

# predict
xgb_y_predict = xgb_model.predict(x_test)

# accuracy score
xgb_score = accuracy_score(xgb_y_predict, y_test)

print('Accuracy score is:', xgb_score)
print('Roc auc scote:', roc_auc_score(xgb_y_predict, y_test))
print('F1 core:',f1_score(xgb_y_predict, y_test))
# Out:
# Accuracy score is: 0.8990825688073395
# Roc auc scote: 0.8923809523809523
# F1 core: 0.8

# %%
confusion_matrix(xgb_y_predict, y_test)
# Out:
# array([[76,  8],
#        [ 3, 22]])

# %% [markdown]
# ##  Resampling Technique

# %%
# class count
class_count_0, class_count_1 = data['Y'].value_counts()

# divie class
class_0 = data[data['Y'] == 0]
class_1 = data[data['Y'] == 1]

# %%
# print the shape of the class
print('class 0:', class_0.shape)
print('\nclass 1:', class_1.shape)
# Out:
# class 0: (274, 4)
#
# class 1: (88, 4)

# %% [markdown]
# ## 1. Random under sampling

# %%
class_0_under = class_0.sample(class_count_1)

test_under = pd.concat([class_0_under, class_1], axis=0)

print("total class of 1 and 0:\n",test_under['Y'].value_counts())

test_under['Y'].value_counts().plot(kind='bar', title='Count (target)')
plt.show()
# Out:
# total class of 1 and 0:
#  0    88
# 1    88
# Name: Y, dtype: int64

# %% [markdown]
# ## 2. Random over sampling

# %%
class_1_over = class_1.sample(class_count_0, replace=True)

test_under = pd.concat([class_1_over, class_0], axis=0)

# print the number of class count
print('class count of 1 and 0:\n', test_under['Y'].value_counts())

# plot the count
test_under['Y'].value_counts().plot(kind='bar', title='Count (target)')
plt.show()
# Out:
# class count of 1 and 0:
#  1    274
# 0    274
# Name: Y, dtype: int64

# %% [markdown]
# ## Balance data with imbalance learn module

# %%
# import library
import imblearn

# %% [markdown]
# ## 3. Random under-sampling with imblearn

# %%
# import library
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(random_state=42, replacement=True)

# fit predictor and target varialbe
x_rus, y_rus = rus.fit_resample(x, y)

print('original dataset shape:', Counter(y))
print('Resample dataset shape', Counter(y_rus))
# Out:
# original dataset shape: Counter({0: 274, 1: 88})
# Resample dataset shape Counter({0: 88, 1: 88})

# %% [markdown]
# ## 4.Random over-sampling with imblearn

# %%
# import library
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(random_state=42)

# fit predictor and target varaible
x_ros, y_ros = ros.fit_resample(x, y)

print('Original dataset shape', Counter(y))
print('Resample dataset shape', Counter(y_ros))
# Out:
# Original dataset shape Counter({0: 274, 1: 88})
# Resample dataset shape Counter({1: 274, 0: 274})

# %% [markdown]
# ## 5. under-sampling Tomek links

# %% [markdown]
# ## 6. Synthetic minority over-sampleing technique

# %%
# load library
from imblearn.over_sampling import SMOTE

smote = SMOTE()

# fit target and predictor variable
x_smote , y_smote = smote.fit_resample(x, y)

print('Origianl dataset shape:', Counter(y))
print('Resampple dataset shape:', Counter(y_smote))
# Out:
# Origianl dataset shape: Counter({0: 274, 1: 88})
# Resampple dataset shape: Counter({1: 274, 0: 274})

# %% [markdown]
# ## 7. NearMiss

# %%
from imblearn.under_sampling import NearMiss

nm = NearMiss()

x_nm, y_nm = nm.fit_resample(x, y)

print('Original dataset shape:', Counter(y))
print('Resample dataset shape:', Counter(y_nm))
# Out:
# Original dataset shape: Counter({0: 274, 1: 88})
# Resample dataset shape: Counter({0: 88, 1: 88})

# %% [markdown]
# ## 8. Change the performance metric

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(x_nm, y_nm, test_size =0.30, random_state=42)

m = XGBClassifier()
m.fit(x_train1, y_train1)
predict_y = m.predict(x_test1)

print('ROCAUC score:',roc_auc_score(y_test1, predict_y))
print('Accuracy score:',accuracy_score(y_test1, predict_y))
print('F1 score:',f1_score(y_test1, predict_y))
# Out:
# ROCAUC score: 0.6766381766381766
# Accuracy score: 0.6792452830188679
# F1 score: 0.6222222222222222

# %% [markdown]
# ## 9. Tree based algorithm

# %%
# load library
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()

# fit the predictor and target
rfc.fit(x_train, y_train)

# predict
rfc_predict = rfc.predict(x_test)

# %%
# check performance

print('ROCAUC score:',roc_auc_score(y_test, rfc_predict))
print('Accuracy score:',accuracy_score(y_test, rfc_predict))
print('F1 score:',f1_score(y_test, rfc_predict))
# Out:
# ROCAUC score: 0.8580168776371307
# Accuracy score: 0.8990825688073395
# F1 score: 0.8070175438596491
